# %%
import os, sys

PROJECT_ROOT = r"E:\Pranav\Engineering\Projects\AEWS"
os.chdir(PROJECT_ROOT)

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
import pandas as pd

enrol = pd.read_csv("data/processed/enrolment_monthly.csv")
demo = pd.read_csv("data/processed/demographic_monthly.csv")
bio = pd.read_csv("data/processed/biometric_monthly.csv")

# %%
from src.metrics.identity_stress_index import IdentityStressIndex

isi_engine = IdentityStressIndex()

isi_df = isi_engine.compute(
    enrol_df=enrol,
    demo_df=demo,
    bio_df=bio
)

isi_df.head()
# Out:
#     state district year_month  enrol_activity  demo_activity  bio_activity  \
# 0  100000   100000    2025-02          100003         200002      14139195
# 1  100000   100000    2025-03          100001       11161793      12649948
# 2  100000   100000    2025-08          100001        9673377       9673415
# 3  100000   100000    2025-09          100001       13393929       7441171
# 4  100000   100000    2025-11          100002       14882372      12650221
#
#      enrol_norm  demo_norm  bio_norm  isi_score
# 0  6.364787e-10   0.000019  0.003578   0.001439
# 1  0.000000e+00   0.002297  0.003198   0.002198
# 2  0.000000e+00   0.001988  0.002439   0.001771
# 3  0.000000e+00   0.002761  0.001870   0.001852
# 4  3.182393e-10   0.003070  0.003198   0.002507

# %%
isi_df.to_csv("data/processed/isi_scores.csv", index=False)
